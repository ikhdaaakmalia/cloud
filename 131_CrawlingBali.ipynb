# %% [markdown]
# <a href="https://colab.research.google.com/github/ikhdaaakmalia/cloud/blob/main/131_CrawlingBali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo[srv]
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# WARNING: pymongo 4.12.1 does not provide the extra 'srv'
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 7.0 MB/s eta 0:00:00
# Downloading pymongo-4.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 31.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.12.1
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)

# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient
import random
import time

# Koneksi ke MongoDB Atlas
client = MongoClient("mongodb+srv://ikhdaamel:sejutasayang@cluster0.lk8xt.mongodb.net/")

def crawl_detik_keyword():
    base_url = 'https://www.detik.com/search/searchall?query=bali'
    collection = client['Crawling_Keyword']['bali']

    # Tentukan jumlah halaman yang ingin di-crawl
    max_page = 5 #total halaman yg mau di crawl
    page = 1 #mulai crawl dari page 1
    while page <= max_page:  # Mengganti kondisi while dengan pembatasan halaman
        url = f'{base_url}&page={page}&result_type=relevansi'
        print(f' Crawling halaman {page} -> {url}')

    #membuka halaman artikel untuk parsing
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'lxml')

        articles = soup.find_all('article')
        if not articles:
            print('✅ Tidak ada lagi artikel, proses crawling selesai.')
            break

        for artikel in articles:
            try:
                link_tag = artikel.find('a')
                link = link_tag['href'] if link_tag else None
                if not link:
                    print('❌ Link tidak ditemukan.')
                    continue

                judul_tag = artikel.find('h3')
                judul = judul_tag.text.strip() if judul_tag else None
                if not judul:
                    print('❌ Judul tidak ditemukan.')
                    continue

                # Cek duplikat berdasarkan link atau judul
                if collection.find_one({'link': link}) or collection.find_one({'judul': judul}):
                    print(f'⏩ Artikel sudah ada: {judul[:50]}...')
                    continue

                isi_res = requests.get(link)
                isi_soup = BeautifulSoup(isi_res.text, 'lxml')

                # Meta info (pengambilan data)
                tanggal_meta = isi_soup.find('meta', attrs={'name': 'dtk:publishdate'})
                tanggal = tanggal_meta['content'].strip() if tanggal_meta else 'Tanggal tidak ditemukan'

                author_meta = isi_soup.find('meta', attrs={'name': 'dtk:author'})
                author = author_meta['content'].strip() if author_meta else 'Tidak tersedia'

                description_meta = isi_soup.find('meta', attrs={'name': 'description'})
                description = description_meta['content'].strip() if description_meta else 'Deskripsi tidak ditemukan'

                tags_meta = isi_soup.find('meta', attrs={'name': 'keywords'})
                tags = tags_meta['content'].strip() if tags_meta else 'Tags tidak ditemukan'

                # Ambil isi berita
                body_content = isi_soup.find('div', class_='detail__body-text itp_bodycontent')
                if body_content and body_content.get('id') != 'detikdetailtext':
                    isi_paragraf_list = [p.get_text(strip=True) for p in body_content.find_all('p') if p.get_text(strip=True)]
                    isi_berita = ' '.join(isi_paragraf_list) if isi_paragraf_list else 'Isi berita tidak ditemukan'
                else:
                    fallback_paragraf = isi_soup.find_all('p')
                    isi_paragraf_list = [p.get_text(strip=True) for p in fallback_paragraf if p.get_text(strip=True)]
                    isi_berita = ' '.join(isi_paragraf_list) if isi_paragraf_list else 'Isi berita tidak ditemukan'

                # Ambil thumbnail
                thumbnail_meta = isi_soup.find('meta', attrs={'name': 'dtk:thumbnailUrl'}) or isi_soup.find('meta', attrs={'property': 'og:image'})
                thumbnail_url = thumbnail_meta['content'].strip() if thumbnail_meta else 'Thumbnail tidak ditemukan'

                # Simpan ke MongoDB
                collection.insert_one({
                    'judul': judul,
                    'tanggal': tanggal,
                    'author': author,
                    'description': description,
                    'tags': tags,
                    'link': link,
                    'isi_berita': isi_berita,
                    'thumbnail': thumbnail_url
                })
                print(f'✅ Simpan: {judul[:50]}...')

                time.sleep(random.uniform(0.1, 0.5)) #jeda tiap data saat crawl

            except Exception as e:
                print(f'❌ Error saat proses artikel: {e}')

        page += 1 #next halaman ketika satu halaman selesai di crawl

# Jalankan crawler
crawl_detik_keyword()
# Out:
#  Crawling halaman 1 -> https://www.detik.com/search/searchall?query=bali&page=1&result_type=relevansi
# ✅ Simpan: Tren Investasi Properti di Bali Begeser, Generasi ...
# ✅ Simpan: Giri Prasta Pastikan Bali Segera Mandiri Energi...
# ✅ Simpan: Bule AS Luntang-Lantung di Bali, Hidup dari Barang...
# ✅ Simpan: Video: Tampang Pelaku Pembunuhan Wanita Driver Onl...
# ✅ Simpan: Buntut Pemadaman Listrik Berjam-jam, PHRI Dorong B...
# ✅ Simpan: Kapolda Bali Minta Anak Buah Tak Ragu Tindak Tegas...
# ✅ Simpan: Bali United Bidik Sapu Bersih Tiga Laga Pamungkas ...
# ✅ Simpan: Melihat Tradisi Mekotek Saat Hari Raya Kuningan...
# ✅ Simpan: Ekonomi Bali Triwulan I 2025 Tumbuh 5,52%, Didomin...
# ✅ Simpan: Respek! Ucapan Selamat untuk Persib dari Dewa hing...
# ✅ Simpan: Tokoh Agama Apresiasi Polda Bali Jaga Keamanan dan...
# ✅ Simpan: Respons Ketua GRIB Bali Seusai Mendapat Penolakan ...
#  Crawling halaman 2 -> https://www.detik.com/search/searchall?query=bali&page=2&result_type=relevansi
# ✅ Simpan: Giri Prasta Wacanakan Pemberian Insentif untuk Pec...
# ✅ Simpan: Listrik di Bali Sempat Padam Massal, ESDM Sarankan...
# ✅ Simpan: Luna Maya-Maxime Bouttier Kerja Sambil Liburan Jel...
# ✅ Simpan: Video IFSC Climbing World Cup Bali 2025: Erin Mcne...
# ✅ Simpan: Pembunuh Perempuan Driver Online Sakit Hati gegara...
# ✅ Simpan: Gading Marten Tak Bisa Hadir ke Pernikahan Luna Ma...
# ✅ Simpan: ESDM Investigasi Penyebab Blackout di Bali...
# ✅ Simpan: Potret Ritual Hari Raya Kuningan...
# ⏩ Artikel sudah ada: Video IFSC Climbing World Cup Bali 2025: Erin Mcne...
# ✅ Simpan: Koster Akan Bahas Polemik Ormas GRIB Jaya di Bali...
# ✅ Simpan: Tolak Ormas GRIB Jaya di Bali, Giri Prasta: Sudah ...
# ✅ Simpan: 5 Ikan Mati gegara Blackout di Bali, Penghobi Koi ...
#  Crawling halaman 3 -> https://www.detik.com/search/searchall?query=bali&page=3&result_type=relevansi
# ✅ Simpan: Desak Rita Dilarang Ikuti Porprov Bali 2025, Kadek...
# ✅ Simpan: Kronologi Pembunuhan Wanita Driver Online yang Jas...
# ✅ Simpan: Ada Pemadaman Listrik di Bali Hari Ini, Cek Jadwal...
# ✅ Simpan: Mengunjungi Cafe Viral yang Instagramable di Semin...
# ✅ Simpan: PLTS 25 MWp di Tianyar Segera Rampung, Karangasem ...
# ✅ Simpan: Mahayastra Tegaskan Perbaikan Jalan yang Rusak di ...
# ✅ Simpan: Siswa di Buleleng Tak Bisa Membaca, Sekolah Dimint...
# ✅ Simpan: Gelap Gulita di Seluruh Bali...
# ✅ Simpan: Sam Watson dan Aleksandra Miroslaw Juarai IFSC 202...
# ✅ Simpan: Video: Blackout di Bali, Bagaimana Kondisi Bandara...
# ✅ Simpan: Listrik se-Pulau Bali Padam, Aktivitas Masyarakat ...
# ✅ Simpan: Bali Blackout Hampir 12 Jam, Ekonomi Terdampak Sig...
#  Crawling halaman 4 -> https://www.detik.com/search/searchall?query=bali&page=4&result_type=relevansi
# ✅ Simpan: PLN Bantah Listrik Padam di Seluruh Bali karena Se...
# ✅ Simpan: Listrik di Bali Menyala Total Pukul 03.30 Wita Usa...
# ✅ Simpan: Lalin Sejumlah Jalan di Bali Tersendat Akibat List...
# ✅ Simpan: Menantang Diri di Lime Challenge di Kolam Renang B...
# ✅ Simpan: PLN Ungkap Penyebab Listrik di Bali Padam, Bukan k...
# ✅ Simpan: Warga Berburu Genset, Senter, hingga Lilin Saat Li...
# ✅ Simpan: PLN Jelaskan Pemicu Listrik Padam di Seluruh Wilay...
# ✅ Simpan: 7 Foto Pernikahan Harris Vriza & Haviza Devi di Ba...
# ✅ Simpan: PLN Sebut 50% Listrik di Bali Sudah Pulih...
# ✅ Simpan: Penerbangan Internasional dari Bali Naik, Domestik...
# ✅ Simpan: Sam Watson Pecahkan Rekor Dunia Panjat Tebing di B...
# ✅ Simpan: Listrik Padam Seluruh Bali, Mensesneg Telepon Bos ...
#  Crawling halaman 5 -> https://www.detik.com/search/searchall?query=bali&page=5&result_type=relevansi
# ✅ Simpan: Yenny Wahid Bersyukur Indonesia Dapat Dua Medali d...
# ✅ Simpan: Listrik Padam di Bali, Ngurah Rai Pakai Genset-Pen...
# ✅ Simpan: Kalender Bali 5 Mei 2025: Baik untuk Upacara Dewa ...
# ✅ Simpan: Bersantai Mengapung di Floaties yang Nyaman di Kol...
# ✅ Simpan: Video: Suasana Malam di Kawasan Kuta saat Listrik ...
# ✅ Simpan: Bali Wisata Dunia, tapi Gaji Pekerjanya Tak Sebera...
# ✅ Simpan: Listrik Padam di Bali, Supermarket Merugi-SPBU Nor...
# ✅ Simpan: Potret Keseruan Parade Membuat Sate Khas Bali...
# ✅ Simpan: Mati Listrik Seluruh Bali hingga Mundur Massal Kad...
# ✅ Simpan: Peran Sosiolog di Balik Panggung IFSC World Cup Ba...
# ✅ Simpan: Diprediksi Berawan, Ini Prakiraan Cuaca Bali Senin...
# ✅ Simpan: Listrik Seluruh Bali Padam Imbas Gangguan Kabel Ba...
